# %% [markdown]
# ## Una cepa de E. coli tiene una taza de crecimiento tal que un individuo se duplica cada 30 minutos

# %% [markdown]
# ### Calcula en cuanto tiempo esta cepa
#
#
# a) Llenaria el volumen de la Tierra (considerando como una esfera hueca y apartir del r de la tierra)
#
# b) Cubriría la superficie de la tierra
#
# c) Repite el cálculo para una tasa de crecimiento
#
#         1) Se duplica cada hora
#
#         2) Se duplica cada 1/4 de hora

# %%
import math as mt

# %%
Ecoli = 0.5

# %%
rt = 6371

# %%
doblert = rt * 1e3

# %%
doblecoli = Ecoli * 1e-6

# %%
N = (doblert)**3 / (doblecoli)**3

# %%
N
# Out:
# 2.0687728224880002e+39

# %%
t = mt.log2(N)

# %%
t
# Out:
# 130.6039709282774

# %%
t2 = t * 2

# %%
t2
# Out:
# 261.2079418565548

# %%
th = t / 2

# %%
td = th / 24

# %%
td
# Out:
# 2.720916061005779
